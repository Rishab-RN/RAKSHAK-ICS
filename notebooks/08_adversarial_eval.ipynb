# %% [markdown]
# # 08 — Adversarial Evaluation & AHG Comparison
#
# This notebook evaluates and compares all attackers against the Fusion Blue Agent defender.

# %%
import os
os.chdir("..")
import json
from pathlib import Path

tables_dir = Path("results/tables")
unified_results_path = tables_dir / "adversarial_eval_results_unified.json"
if unified_results_path.exists():
    with open(unified_results_path, "r") as f:
        results = json.load(f)
    print(json.dumps(results, indent=2))
else:
    print("Unified results not found. Ensure src.evaluate has run.")
