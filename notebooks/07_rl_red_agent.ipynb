# %% [markdown]
# # 07 — Reinforcement Learning: DQN Red Agent Attacker
#
# **RAKSHAK-ICS** | Week 6 — Coordinated FDI Attacks via RL
#
# This notebook trains the **DQN Red Agent attacker** in the  Gymnasium environment.

# %%
import os
os.chdir("..")
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# Plot saved reward curves
reward_curve_path = Path("results/figures/dqn_reward_curve.png")
if reward_curve_path.exists():
    img = plt.imread(reward_curve_path)
    plt.figure(figsize=(12, 6))
    plt.imshow(img)
    plt.axis("off")
    plt.show()
else:
    print("Reward curve figure not found! Ensure src.rl_train has run first.")
